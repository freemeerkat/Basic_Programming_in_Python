# %% [markdown]
# # This is the notebook for the first seminar session of "Basic Programming in Python" of the SoSe26"

# %%
test = "abcdefg"

for idx in range(len(test)-2):
    print(test[idx])
# Out:
# a
# b
# c
# d
# e
